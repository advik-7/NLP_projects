# %% [markdown]
# <a href="https://colab.research.google.com/github/advik-7/NLP_projects/blob/main/Sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import nltk

# %%
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sia=SentimentIntensityAnalyzer()

# %%
import os
amazon_review = 'amazon_review'
os.mkdir(amazon_review)

# %%
import zipfile
with zipfile.ZipFile("/content/test.csv.zip", 'r') as zip_ref:
    zip_ref.extractall(amazon_review)

# %%
df=pd.read_csv("/content/amazon_review/test.csv")

# %%
df.shape
# Out:
# (399999, 3)

# %%
df.head()
# Out:
#    2                                           Great CD  \
# 0  2  One of the best game music soundtracks - for a...
# 1  1                   Batteries died within a year ...
# 2  2              works fine, but Maha Energy is better
# 3  2                       Great for the non-audiophile
# 4  1              DVD Player crapped out after one year
#
#   My lovely Pat has one of the GREAT voices of her generation. I have listened to this CD for YEARS and I still LOVE IT. When I'm in a good mood it makes me feel better. A bad mood just evaporates like sugar in the rain. This CD just oozes LIFE. Vocals are jusat STUUNNING and lyrics just kill. One of life's hidden gems. This is a desert isle CD in my book. Why she never made it big is just beyond me. Everytime I play this, no matter black, white, young, old, male, female EVERYBODY says one thing "Who was that singing ?"
# 0  Despite the fact that I have only played a sma...
# 1  I bought this charger in Jul 2003 and it worke...
# ...

# %%
df.isnull().sum()
# Out:
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0
# ...

# %%
# Drop the lengthy column
df = df.drop(columns=["My lovely Pat has one of the GREAT voices of her generation. I have listened to this CD for YEARS and I still LOVE IT. When I'm in a good mood it makes me feel better. A bad mood just evaporates like sugar in the rain. This CD just oozes LIFE. Vocals are jusat STUUNNING and lyrics just kill. One of life's hidden gems. This is a desert isle CD in my book. Why she never made it big is just beyond me. Everytime I play this, no matter black, white, young, old, male, female EVERYBODY says one thing \"Who was that singing ?\""])

# %%
df.head()
# Out:
#    2                                           Great CD
# 0  2  One of the best game music soundtracks - for a...
# 1  1                   Batteries died within a year ...
# 2  2              works fine, but Maha Energy is better
# 3  2                       Great for the non-audiophile
# 4  1              DVD Player crapped out after one year

# %%
df=df.rename(columns={'2':"label",'Great CD':"review"})

# %%
df.head()
# Out:
#    label                                             review
# 0      2  One of the best game music soundtracks - for a...
# 1      1                   Batteries died within a year ...
# 2      2              works fine, but Maha Energy is better
# 3      2                       Great for the non-audiophile
# 4      1              DVD Player crapped out after one year

# %%
df.isnull().sum()
# Out:
# label      0
# review    24
# dtype: int64

# %%
df_cleaned=df.dropna(axis=0)

# %%
df_cleaned.isnull().sum()
# Out:
# label     0
# review    0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# 1    200000
# 2    199999
# Name: count, dtype: int64

# %%
df.iloc[0]['review']
# Out:
# "One of the best game music soundtracks - for a game I didn't really play"

# %%
sia.polarity_scores(df.iloc[0]['review'])
# Out:
# {'neg': 0.137, 'neu': 0.608, 'pos': 0.255, 'compound': 0.4492}

# %%
df['review'] = df['review'].astype(str)

# %%
df['scores']=df['review'].apply(lambda review: sia.polarity_scores(review))

# %%
df.head()
# Out:
#    label                                             review  \
# 0      2  One of the best game music soundtracks - for a...
# 1      1                   Batteries died within a year ...
# 2      2              works fine, but Maha Energy is better
# 3      2                       Great for the non-audiophile
# 4      1              DVD Player crapped out after one year
#
#                                               scores
# 0  {'neg': 0.137, 'neu': 0.608, 'pos': 0.255, 'co...
# 1  {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'comp...
# 2  {'neg': 0.0, 'neu': 0.336, 'pos': 0.664, 'comp...
# 3  {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'comp...
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...

# %%
df['compound']=df['scores'].apply(lambda d:d['compound'])

# %%
df.head()
# Out:
#    label                                             review  \
# 0      2  One of the best game music soundtracks - for a...
# 1      1                   Batteries died within a year ...
# 2      2              works fine, but Maha Energy is better
# 3      2                       Great for the non-audiophile
# 4      1              DVD Player crapped out after one year
#
#                                               scores  compound
# 0  {'neg': 0.137, 'neu': 0.608, 'pos': 0.255, 'co...    0.4492
# 1  {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'comp...   -0.5574
# 2  {'neg': 0.0, 'neu': 0.336, 'pos': 0.664, 'comp...    0.7845
# 3  {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'comp...    0.6249
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000

# %%
df["compound_score"]=df['compound'].apply(lambda score: 'pos' if score>0 else 'neg')

# %%
df.drop(columns=["scores"])
# Out:
#         label                                             review  compound  \
# 0           2  One of the best game music soundtracks - for a...    0.4492
# 1           1                   Batteries died within a year ...   -0.5574
# 2           2              works fine, but Maha Energy is better    0.7845
# 3           2                       Great for the non-audiophile    0.6249
# 4           1              DVD Player crapped out after one year    0.0000
# ...       ...                                                ...       ...
# 399994      1                         Unbelievable- In a Bad Way   -0.4019
# 399995      1                    Almost Great, Until it Broke...    0.5868
# 399996      1                                   Disappointed !!!   -0.6093
# 399997      2                            Classic Jessica Mitford    0.0000
# 399998      1                        Comedy Scene, and Not Heard    0.3612
#
#        compound_score
# 0                 pos
# ...
